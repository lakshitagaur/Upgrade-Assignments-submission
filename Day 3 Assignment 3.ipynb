# %% [markdown]
# # Day 3 Assignment 3
#
# ### Lakshita Gaur

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
fmri=sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='event',hue='region',data=fmri)

# %%
fmri['event'].unique()
# Out:
# array(['stim', 'cue'], dtype=object)

# %%
sns.relplot(x='timepoint',y='signal',hue='region',data=fmri)

# %%
sns.boxplot(x='timepoint',y='subject',hue='region',data=fmri)

# %%
sns.boxplot(x='timepoint',y='region',hue='event',data=fmri)

# %%
sns.catplot(x='signal',y='event',hue='region',orient='horizontal',legend_out=True,kind='boxen',data=fmri)

# %%
sns.relplot(x='signal',y='timepoint',hue='region',kind='line',data=fmri,sort=True,height=10)

# %%
sns.catplot(x='signal',y='event',hue='region',orient='horizontal',legend_out=True,kind='swarm',data=fmri)

# %%
sns.catplot(x='signal',y='subject',hue='region',orient='horizontal',legend_out=True,kind='violin',data=fmri,height=8,aspect=1)
