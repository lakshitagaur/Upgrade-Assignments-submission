# %% [markdown]
# # Day 1 Assignment (Lakshita Gaur)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mlb

# %%
#Question 1
##Plot a line plot between a and b:

#a=np.arange(40,50)
#b=np.arange(50,60)

# %%
a=np.arange(40,50)
b=np.arange(50,60)
plt.title("Question 1 line chart")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot(a,b,"y*-",markersize=9,linewidth=2)

# %%
#Question 2
#Plot a line plot showing the sales trend in company 1 and 2:

days = [1,2,3,4,5,6,7] #days of d week
sales_1 = [160,150,140,145,175,165,180] #sales of company1
sales_2 = [70,90,160,150,140,145,175]  #sales of company2

# %%
plt.title("Sales Comparison between two companies")
plt.xlabel("Days")
plt.ylabel("Sales")
plt.plot(days, sales_1,"b--",markersize=3)
plt.plot(days,sales_2,'mo-',markersize=2)

# %%
# Question 3
#  Create a 3 by 3 subplots:
# multiple plots

x = [1,2,3,4]
y1 = [4,3,2,1]
y2 = [10,20,30,40]
y3 = [40,30,20,10]
y4 = [1,2,1,2]
y5 = [40,70,90,70]

# %%
plt.figzise=
plt.subplot(3,3,1)
plt.plot(x,y1,'m--')
plt.subplot(3,3,2)
plt.plot(x,y2,'b--')
plt.subplot(3,3,3)
plt.plot(x,y3,'o--')
plt.subplot(3,3,4)
plt.plot(x,y4,'r--')
plt.subplot(3,3,5)
plt.plot(x,y5,'y--')
plt.subplot(3,3,6)
plt.plot(y2,y3,'g--')
plt.subplot(3,3,7)
plt.plot(x,y3,'o--')
plt.subplot(3,3,8)
plt.plot(y4,x,'k--')
plt.subplot(3,3,9)
plt.plot(y2,y2,'c--')
